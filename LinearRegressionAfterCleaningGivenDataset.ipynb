# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading Data
data = pd.read_csv('share.csv')
data.head()
# Out:
#                         County   FIPS Met Objective of 45.5? (1)  \
# 0                United States      0                         No
# 1       Perry County, Kentucky  21193                         No
# 2      Powell County, Kentucky  21197                         No
# 3  North Slope Borough, Alaska   2185                         No
# 4      Owsley County, Kentucky  21189                         No
#
#   Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                      46                                         45.9
# 1                   125.6                                        108.9
# 2                   125.3                                        100.2
# 3                   124.9                                           73
# 4                   118.5                                         83.1
#
#   Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 0                                         46.1                1,57,376
# ...

# %%
#Replacing the * with NaN value in the given dataset
data.replace('*', np.NaN, inplace = True)
data.replace('**', np.NaN, inplace = True)
data.head()
# Out:
#                         County   FIPS Met Objective of 45.5? (1)  \
# 0                United States      0                         No
# 1       Perry County, Kentucky  21193                         No
# 2      Powell County, Kentucky  21197                         No
# 3  North Slope Borough, Alaska   2185                         No
# 4      Owsley County, Kentucky  21189                         No
#
#   Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                      46                                         45.9
# 1                   125.6                                        108.9
# 2                   125.3                                        100.2
# 3                   124.9                                           73
# 4                   118.5                                         83.1
#
#   Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 0                                         46.1                1,57,376
# ...

# %%
print(len(data))
# Out:
# 3141

# %%
#Dropping the rows having non - NaN values in less than 3 columns
data.dropna(inplace = True, thresh = 3)

# %%
print(len(data))
# Out:
# 2813

# %%
data.head(len(data))
# Out:
#                            County   FIPS Met Objective of 45.5? (1)  \
# 0                   United States      0                         No
# 1          Perry County, Kentucky  21193                         No
# 2         Powell County, Kentucky  21197                         No
# 3     North Slope Borough, Alaska   2185                         No
# 4         Owsley County, Kentucky  21189                         No
# ...                           ...    ...                        ...
# 2808       Eagle County, Colorado   8037                        Yes
# 2809          Summit County, Utah  49043                        Yes
# 2810            Utah County, Utah  49049                        Yes
# 2811  McKinley County, New Mexico  35031                        Yes
# 2812           Cache County, Utah  49005                        Yes
#
#      Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                         46                                         45.9
# ...

# %%
#Replacing the NaN values with the mean of the respective column
data['Recent 5-Year Trend (2) in Death Rates'] = data['Recent 5-Year Trend (2) in Death Rates'].apply(lambda x : float(x))
data['Recent 5-Year Trend (2) in Death Rates'].replace(np.NaN, data['Recent 5-Year Trend (2) in Death Rates'].mean(), inplace = True)
data['Recent 5-Year Trend (2) in Death Rates'].head(len(data))
# Out:
# 0      -2.400000
# 1      -0.600000
# 2       1.700000
# 3      -1.003526
# 4       2.200000
#           ...
# 2808   -4.900000
# 2809   -1.003526
# 2810   -2.800000
# 2811   -3.200000
# 2812   -0.700000
# Name: Recent 5-Year Trend (2) in Death Rates, Length: 2813, dtype: float64

# %%
#Replacing the NaN values with the mean of the respective column
data['Lower 95% Confidence Interval for Trend'] = data['Lower 95% Confidence Interval for Trend'].apply(lambda x : float(x))
data['Lower 95% Confidence Interval for Trend'].replace(np.NaN, data['Lower 95% Confidence Interval for Trend'].mean(), inplace = True)
data['Lower 95% Confidence Interval for Trend'].head(len(data))
# Out:
# 0      -2.600000
# 1      -2.700000
# 2       0.000000
# 3      -2.755939
# 4      -0.400000
#           ...
# 2808   -9.300000
# 2809   -2.755939
# 2810   -3.900000
# 2811   -5.700000
# 2812   -3.000000
# Name: Lower 95% Confidence Interval for Trend, Length: 2813, dtype: float64

# %%
#Replacing the NaN values with the mean of the respective column
data['Upper 95% Confidence Interval for Trend'] = data['Upper 95% Confidence Interval for Trend'].apply(lambda x : float(x))
data['Upper 95% Confidence Interval for Trend'].replace(np.NaN, data['Upper 95% Confidence Interval for Trend'].mean(), inplace = True)
data['Upper 95% Confidence Interval for Trend'].head(len(data))
# Out:
# 0      -2.200000
# 1       1.600000
# 2       3.400000
# 3       0.837305
# 4       4.800000
#           ...
# 2808   -0.300000
# 2809    0.837305
# 2810   -1.800000
# 2811   -0.700000
# 2812    1.600000
# Name: Upper 95% Confidence Interval for Trend, Length: 2813, dtype: float64

# %%
data.head(len(data))
# Out:
#                            County   FIPS Met Objective of 45.5? (1)  \
# 0                   United States      0                         No
# 1          Perry County, Kentucky  21193                         No
# 2         Powell County, Kentucky  21197                         No
# 3     North Slope Borough, Alaska   2185                         No
# 4         Owsley County, Kentucky  21189                         No
# ...                           ...    ...                        ...
# 2808       Eagle County, Colorado   8037                        Yes
# 2809          Summit County, Utah  49043                        Yes
# 2810            Utah County, Utah  49049                        Yes
# 2811  McKinley County, New Mexico  35031                        Yes
# 2812           Cache County, Utah  49005                        Yes
#
#      Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                         46                                         45.9
# ...

# %%
X = data['Recent 5-Year Trend (2) in Death Rates'].values
Y = data['Lower 95% Confidence Interval for Trend'].values

# %%
#Mean x and y
mean_x = np.mean(X)
mean_y = np.mean(Y)
print("Mean x = ", mean_x)
print("Mean y = ", mean_y)
# Out:
# Mean x =  -1.0035263548626578
# Mean y =  -2.755939123979213

# %%
#Calculating b0 and b1
num = 0
den = 0
for i in range(len(X)):
    num += (X[i] - mean_x) * (Y[i] - mean_y)
    den += (X[i] - mean_x) ** 2
b1 = num / den
b0 = mean_y - (b1 * mean_x)
print("b1 = ", b1, "b0 = ", b0)
# Out:
# b1 =  1.1999893584865748 b0 =  -1.5517181771832012

# %%
#Plotting Values
max_x = np.max(X) + 20
min_x = np.min(X) - 20

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color = "blue", label = "Regression Line")
plt.scatter(X, Y, color = "red", label = "Scatter Point")
plt.xlabel("Recent 5-Year Trend (2) in Death Rates")
plt.ylabel("Lower 95% Confidence Interval for Trend")
plt.legend()
plt.show()

# %%
#Calculating Error
rmse = 0
for i in range(len(X)):
    y_pred = b0 + b1 * X[i]
    rmse += (Y[i] - y_pred) ** 2
rmse = np.sqrt(rmse / len(X))
print("RMSE = ", rmse)
# Out:
# RMSE =  1.8974916688654428

# %%
X = data['Lower 95% Confidence Interval for Trend'].values
Y = data['Upper 95% Confidence Interval for Trend'].values

# %%
#Mean x and y
mean_x = np.mean(X)
mean_y = np.mean(Y)
print("Mean x = ", mean_x)
print("Mean y = ", mean_y)
# Out:
# Mean x =  -2.755939123979213
# Mean y =  0.8373051224944321

# %%
#Calculating b0 and b1
num = 0
den = 0
for i in range(len(X)):
    num += (X[i] - mean_x) * (Y[i] - mean_y)
    den += (X[i] - mean_x) ** 2
b1 = num / den
b0 = mean_y - (b1 * mean_x)
print("b1 = ", b1, "b0 = ", b0)
# Out:
# b1 =  -0.0064214792423674776 b0 =  0.8196079166165712

# %%
#Plotting Values
max_x = np.max(X) + 20
min_x = np.min(X) - 20

x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

plt.plot(x, y, color = "blue", label = "Regression Line")
plt.scatter(X, Y, color = "red", label = "Scatter Point")
plt.xlabel("Lower 95% Confidence Interval for Trend")
plt.ylabel("Upper 95% Confidence Interval for Trend")
plt.legend()
plt.show()

# %%
#Calculating Error
rmse = 0
for i in range(len(X)):
    y_pred = b0 + b1 * X[i]
    rmse += (Y[i] - y_pred) ** 2
rmse = np.sqrt(rmse / len(X))
print("RMSE = ", rmse)
# Out:
# RMSE =  3.016816454092169
